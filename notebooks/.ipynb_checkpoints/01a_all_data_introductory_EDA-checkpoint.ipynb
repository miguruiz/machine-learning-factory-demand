# %% [markdown]
# # TRANSACTIONS TO PARTIAL RESULTS:
#
# This script intends to make an exploratory data analysis on the partially-treated data to jump to our first conclussions.

# %% [markdown]
# # 0. INDEX
#
# <a href='#a1'>1. IMPORTING PACKAGES AND THE INFORMATION</a>
#
#
# <a href='#a2'>2. CHECKING FOR NULL VALUES</a>
#
#
# <a href='#a3'>3. FIRST EVALUATIONS OF THE DATA</a>
#
#
# <a href='#a31'>3.1. Checking the number of different ids and plotting their count</a>
#
# <a href='#a32'>3.2. Adding all the orders for each id and getting first totals and sells share</a>
#
# <a href='#a321'>3.2.1. First problem</a>
#
# <a href='#a322'>3.2.2. Getting the totals</a>
#
# <a href='#a323'>3.2.3. Getting total shares</a>
#
# <a href='#a324'>3.2.4. Second problem</a>
#
#
# <a href='#a4'>4. ENDING</a>

# %% [markdown]
# # 1. IMPORTING PACKAGES AND THE INFORMATION<a id='a1'></a>

# %%
# Importing packages:

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
#Defining the search path of the file, the name and the separator:

file_path = "../data/01_raw/"
file_name = "1_b2-transactions.csv"

sep=";"


# Provisional file:

total_sales_results_per_id="total_sales_results_per_id.csv"
total_sales_results_per_id_and_store="total_sales_results_per_id_and_store.csv"

# %%
# Now, we import the file and storing it in df: 
# (at first, we only import several thousand rows)

df=pd.read_csv(file_path+file_name, nrows=1000000, sep=sep)
df.head()
# Out:
#    product_id                description  order_date  section store  \
# 0       211.0        EMPANADILLAS SALMON  2009-06-12        0  BmUP
# 1      1231.0  MALLORCA CELOFAN VAINILLA  2009-06-13        0  BmUP
# 2      1233.0       ROCAS FILET VAINILLA  2009-06-13        0  BmUP
# 3      1234.0              LICOR GUINDAS  2009-06-13        0  BmUP
# 4      1235.0                 LICOR UVAS  2009-06-13        0  BmUP
#
#   units_ordered
# 0          0,00
# 1          0,00
# 2          1,00
# 3          1,00
# 4          1,00

# %%
df.shape
# Out:
# (1000000, 6)

# %%
df.columns
# Out:
# Index(['product_id', 'description', 'order_date', 'section', 'store',
#        'units_ordered'],
#       dtype='object')

# %% [markdown]
# # 2. CHECKING FOR NULL VALUES<a id='a2'></a>

# %%
# Checking if is there any null values:

df.isnull().values.any()
# Out:
# True

# %%
# Also checking the na values:

df.isna().values.any()
# Out:
# True

# %%
# We now proceed to take a look on the

import seaborn as sns

sns.heatmap(df.isnull(), cbar=False)

# %%
# We can construct a vector for selecting those rows that have any missing data:

# First we create a boleean array that tells us wether the row has missing data:

missing_data_check=False
for column in df.columns:
    missing_data_check = missing_data_check |df[column].isnull()
    
# We can now slice the column to get only those columns that have missing data:

array_of_missing_values=missing_data_check[missing_data_check==True]

# %%
# We now check the lenght of this resulting vector:

len(array_of_missing_values)
# Out:
# 1056

# %%
# After checking that the % of the missing data rows is despicable (for 1000000 rows we get 1056, or 0.1%), we decide to drop them:

df.dropna(how='any', inplace=True)

# %% [markdown]
# # 3. FIRST EVALUATIONS OF THE DATA<a id='a3'></a>

# %% [markdown]
# ## 3.1. Checking the number of different ids and plotting their count<a id='a31'></a>

# %%
# Taking a look of how many different ids exist and their totals (in our 10.000 rows, of course):

prod_and_num_trans=df.groupby('product_id').count()['description'].sort_values(ascending=False)
prod_and_num_trans
# Out:
# product_id
# 9999.0    24853
# 202.0      7422
# 451.0      5360
# 459.0      5286
# 450.0      4953
# 887.0      4606
# 410.0      4589
# 453.0      4546
# 209.0      4331
# 296.0      4294
# 463.0      4127
# 291.0      4113
# 411.0      4046
# 203.0      3846
# 201.0      3813
# 820.0      3773
# 452.0      3761
# 230.0      3742
# 101.0      3738
# 464.0      3730
# 413.0      3708
# 846.0      3708
# 446.0      3698
# 295.0      3687
# 865.0      3672
# 462.0      3653
# 182.0      3602
# 428.0      3587
# 402.0      3578
# 227.0      3575
#           ...
# 200.0         1
# 1261.0        1
# 1256.0        1
# 1255.0        1
# 4477.0        1
# 195.0         1
# 699.0         1
# 705.0         1
# 1038.0        1
# 1286.0        1
# 472.0         1
# 9018.0        1
# 8702.0        1
# 2956.0        1
# 491.0         1
# 620.0         1
# 253.0         1
# 248.0         1
# 247.0         1
# 476.0         1
# 8736.0        1
# 9012.0        1
# 8737.0        1
# 8753.0        1
# 8819.0        1
# 1303.0        1
# 9008.0        1
# 474.0         1
# 9009.0        1
# 617.0         1
# Name: description, Length: 1885, dtype: int64

# %%
# We want to take a look for checking how many different values exist in our df:

len(prod_and_num_trans)

# The result is that in the first 100.000 rows we have 1283 unique ids.
# Out:
# 1885

# %%
best_sellers_list=prod_and_num_trans.iloc[0:50]
best_sellers_list
# Out:
# product_id
# 9999.0    24853
# 202.0      7422
# 451.0      5360
# 459.0      5286
# 450.0      4953
# 887.0      4606
# 410.0      4589
# 453.0      4546
# 209.0      4331
# 296.0      4294
# 463.0      4127
# 291.0      4113
# 411.0      4046
# 203.0      3846
# 201.0      3813
# 820.0      3773
# 452.0      3761
# 230.0      3742
# 101.0      3738
# 464.0      3730
# 413.0      3708
# 846.0      3708
# 446.0      3698
# 295.0      3687
# 865.0      3672
# 462.0      3653
# 182.0      3602
# 428.0      3587
# 402.0      3578
# 227.0      3575
# 231.0      3545
# 816.0      3534
# 521.0      3484
# 140.0      3445
# 103.0      3438
# 271.0      3385
# 229.0      3345
# 204.0      3336
# 228.0      3312
# 177.0      3276
# 272.0      3234
# 914.0      3165
# 242.0      3162
# 461.0      3129
# 293.0      3096
# 102.0      3060
# 142.0      3060
# 298.0      3055
# 457.0      3050
# 720.0      3047
# Name: description, dtype: int64

# %%
names=[str(x) for x in best_sellers_list.index]
plt.bar(names, height=best_sellers_list.values);

# %% [markdown]
# ## 3.2. Adding all the orders for each id and getting first totals and sells share<a id='a32'></a>

# %% [markdown]
# ## 3.2.1. First problem:<a id='a321'></a>

# %% [markdown]
# We face our first problem here. The information on units oredered is not of type integer, as we would like to have it, but
# it is a string. We have to convert it appropriately before going on:

# %%
type(df['units_ordered'][5])
# Out:
# str

# %%
# Quick check on the different positions the comma might be at:

comma_positions=df['units_ordered'].str.find(",")
comma_positions.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
# The 'units_ordered' column is a string, that cannot be easily converted to integer because
# their numbers are in continental format ("," instead of "." for decimals).

# So, we decide to separate the string by the comma, take the first partition and store it in the df as an integer (long, in
# provision of numbers in the order of magnitude of the limit of the standard 'int' ~ 31500):

df['units_ordered_numeric']=df['units_ordered'].str.split(",").str[0].astype(dtype='long')

df.columns
# Out:
# Index(['product_id', 'description', 'order_date', 'section', 'store',
#        'units_ordered', 'units_ordered_numeric'],
#       dtype='object')

# %% [markdown]
# ## 3.2.2. Getting the totals:<a id='a322'></a>

# %%
# We take a quick glance to the results to check that everything is fine:

df.head(20)
# Out:
#     product_id                description  order_date  section store  \
# 0        211.0        EMPANADILLAS SALMON  2009-06-12        0  BmUP
# 1       1231.0  MALLORCA CELOFAN VAINILLA  2009-06-13        0  BmUP
# 2       1233.0       ROCAS FILET VAINILLA  2009-06-13        0  BmUP
# 3       1234.0              LICOR GUINDAS  2009-06-13        0  BmUP
# 4       1235.0                 LICOR UVAS  2009-06-13        0  BmUP
# 5       1237.0              TRUFAS WHISKY  2009-06-13        0  BmUP
# 6       1238.0        TRUFAS HELADAS CAFE  2009-06-13        0  BmUP
# 7       1239.0     TRUFAS HELADAS PRALINE  2009-06-13        0  BmUP
# 8       1240.0        TRUFAS HELADAS COCO  2009-06-13        0  BmUP
# 9       1242.0         TRUFAS HELADAS RON  2009-06-13        0  BmUP
# 10      1243.0        TRUFAS HELADAS NATA  2009-06-13        0  BmUP
# 11      1244.0    TRUFAS HELADAS GRANILLO  2009-06-13        0  BmUP
# 12      1245.0    TRUFAS GRANILLO GIGANTE  2009-06-13        0  BmUP
# 13      1257.0        HOJA PRALINE AMARGO  2009-06-13        0  BmUP
# 14       570.0       MACARRON DE PISTACHO  2009-06-13        0  BmUP
# 15       359.0              ARROZ  BLANCO  2009-06-16        0  BmUP
# 16       363.0                VICHISSOISE  2009-06-16        0  BmUP
# 17       363.0                VICHISSOISE  2009-06-16        0  BmUP
# 18       364.0               HUEVO HILADO  2009-06-16        0  BmUP
# 19       365.0          GALANTINA DE PATO  2009-06-16        0  BmUP
#
#    units_ordered  units_ordered_numeric
# 0           0,00                      0
# 1           0,00                      0
# 2           1,00                      1
# 3           1,00                      1
# 4           1,00                      1
# 5           1,00                      1
# 6           1,00                      1
# 7           0,00                      0
# 8           1,00                      1
# 9           0,00                      0
# 10          2,00                      2
# 11          1,00                      1
# 12          0,00                      0
# 13          0,00                      0
# 14          0,00                      0
# 15          0,00                      0
# 16          5,00                      5
# 17          0,00                      0
# 18          0,00                      0
# 19          0,00                      0

# %%
# Proceeding to check the products:

# We want to group by id and description no. What we want to check now is:

    # Wheter there are ids assigned to several product or there are not
    # If an id is assigned to several product, we want to check if there is a logical relationship among those products
    # The quantities of the products bought along the lines we have selected

totals_by_id_description=df.groupby(['product_id', 'description'], as_index=False).sum().sort_values('units_ordered_numeric', ascending=False)
totals_by_id_description.head()
# Out:
#       product_id          description  section  units_ordered_numeric
# 2745       245.0  Sandwiches Surtidos        0                  78850
# 1527       150.0     TORRIJAS GRANDES        0                  62339
# 3105       271.0   MINI QUICHES JAMON        0                  59407
# 3111       272.0  MINI QUICHES SALMON        0                  54600
# 1142       112.0             TORTELES        0                  34976

# %%
total_sales=totals_by_id_description.sum()[3]
total_sales
# Out:
# 1554180

# %% [markdown]
# ## 3.2.3. Getting total shares:<a id='a323'></a>

# %%
totals_by_id_description['sells_share']=totals_by_id_description['units_ordered_numeric']/total_sales

totals_by_id_description.head()
# Out:
#       product_id          description  section  units_ordered_numeric  \
# 2745       245.0  Sandwiches Surtidos        0                  78850
# 1527       150.0     TORRIJAS GRANDES        0                  62339
# 3105       271.0   MINI QUICHES JAMON        0                  59407
# 3111       272.0  MINI QUICHES SALMON        0                  54600
# 1142       112.0             TORTELES        0                  34976
#
#       sells_share
# 2745     0.050734
# 1527     0.040111
# 3105     0.038224
# 3111     0.035131
# 1142     0.022504

# %% [markdown]
# ## 3.2.4. Second problem:<a id='a324'></a>
#
# We have a slight problem with the data, which is the relation id-description is not unique, as e can see below:

# %%
totals_by_id_description[totals_by_id_description['product_id']==245].head(20)
# Out:
#       product_id                                        description  section  \
# 2745       245.0                                Sandwiches Surtidos        0
# 2905       245.0        Sandwiches Surtidos QUE NO LLEVE NADA CERDO        0
# 2992       245.0                               Sandwiches VEGETALES        0
# 2983       245.0  Sandwiches SurtidosSANDHICHS MIXTOS,VEGETALES,...        0
# 2757       245.0           Sandwiches Surtidos  8  de   cada  clase        0
# 2783       245.0                Sandwiches Surtidos , NADA DE CERDO        0
# 2912       245.0                      Sandwiches Surtidos SIN CERDO        0
# 2739       245.0  Sandwiches SOLO DE CANGREJO POLLO ATUN SALMON ...        0
# 2887       245.0  Sandwiches Surtidos DE ATUN 10,POLLO 10,VEGETA...        0
# 2937       245.0             Sandwiches Surtidos variados, NO CERDO        0
# 2900       245.0                       Sandwiches Surtidos NO CERDO        0
# 2982       245.0  Sandwiches SurtidosMIXTOS 10,SALMON 10, VEGETA...        0
# 3038       245.0                               SandwichesDE VEGETAL        0
# 2914       245.0              Sandwiches Surtidos SIN NADA DD CERDO        0
# 2963       245.0          Sandwiches Surtidos------Solo de Pollo---        0
# 2746       245.0                               Sandwiches Surtidos         0
# 2583       245.0              SANDWICHES QUE NO LLEVE NADA DE CERDO        0
# 2728       245.0                               Sandwiches ROQUEFORT        0
# 2843       245.0  Sandwiches Surtidos 3 DE CADA CLASE MENOS CANG...        0
# 2581       245.0                                    SANDWHIS MIXTOS        0
#
#       units_ordered_numeric  sells_share
# 2745                  78850     0.050734
# 2905                    100     0.000064
# 2992                     95     0.000061
# 2983                     75     0.000048
# 2757                     64     0.000041
# 2783                     50     0.000032
# 2912                     40     0.000026
# 2739                     40     0.000026
# 2887                     40     0.000026
# 2937                     40     0.000026
# 2900                     40     0.000026
# 2982                     35     0.000023
# 3038                     30     0.000019
# 2914                     30     0.000019
# 2963                     25     0.000016
# 2746                     24     0.000015
# 2583                     24     0.000015
# 2728                     23     0.000015
# 2843                     21     0.000014
# 2581                     20     0.000013

# %% [markdown]
# We then, proceed to count and order:

# %%
# An accesory table is created to store the counting for each id, then this table is 
# adjoined to our main df: totals_by_id_description

accesory_table_1=totals_by_id_description.groupby('product_id').count()
accesory_table_1.columns=['count', 'count2', 'count3', 'count4']

totals_by_id_description.merge(accesory_table_1['count'], on='product_id').sort_values('count', ascending=False).head(20)
# Out:
#        product_id                                        description  section  \
# 16789      9999.0  TARTA SELVA NEGRA DEL 2, CARTEL. FELICIDADES P...        0
# 13289      9999.0          EncargoTARTA MOUSSE TRES CHOCOLATES DEL 4        0
# 13296      9999.0           Encargo 30 TROZOS DE SALMON A LA NARANJA        0
# 13295      9999.0           EncargoTARTA MOUSSE DE TRES CHOCOLATES 4        0
# 13294      9999.0   EncargoTARTA MOUSSE TRES  CHOCOLATES 16 RACIONES        0
# 13293      9999.0                   EncargoTARTA MOUSSE TRES CHOCO 5        0
# 13292      9999.0  EncargoTARTA MOUSSE TRES CHOCOLAES 5 FELICIDAD...        0
# 13291      9999.0  EncargoTARTA MOUSSE TRES CHOCOLATES 2 ESCRITO ...        0
# 13290      9999.0  EncargoTARTA MOUSSE TRES CHOCOLATES DE 16 RACI...        0
# 13288      9999.0  EncargoTARTA MUS 3 CHOCOLATES 5 ESCRITO SOBRE ...        0
# 13279      9999.0                     EncargoTARTA OPERA DEL PRIMERO        0
# 13287      9999.0                EncargoTARTA MUS 3 CHOCOLATES DEL 5        0
# 13286      9999.0             EncargoTARTA MUS DE 3 CHOCOLATES DEL 1        0
# 13285      9999.0  EncargoTARTA OPERA  CON EL DIBUJO TRAIDO POR E...        0
# 13284      9999.0                    Encargo 2 CHOCOLATINAS CON FOTO        0
# 13283      9999.0                           EncargoTARTA OPERA  DEL4        0
# 13282      9999.0      Encargo 180 RAC DE TARTA DE LIMON EN 6 TARTAS        0
# 13281      9999.0  EncargoTARTA OPERA DEL 5..DIBUJAR UNA MINI Y E...        0
# 13297      9999.0      EncargoTARTA MOUSSE DE TRES CHOCOLATES 16 RAC        0
# 13298      9999.0       EncargoTARTA MOUSSE DE TRES CHOCOLATE DEL 4.        0
#
#        units_ordered_numeric  sells_share  count
# 16789                      0          0.0  17684
# 13289                      0          0.0  17684
# 13296                      0          0.0  17684
# 13295                      0          0.0  17684
# 13294                      0          0.0  17684
# 13293                      0          0.0  17684
# 13292                      0          0.0  17684
# 13291                      0          0.0  17684
# 13290                      0          0.0  17684
# 13288                      0          0.0  17684
# 13279                      0          0.0  17684
# 13287                      0          0.0  17684
# 13286                      0          0.0  17684
# 13285                      0          0.0  17684
# 13284                      0          0.0  17684
# 13283                      0          0.0  17684
# 13282                      0          0.0  17684
# 13281                      0          0.0  17684
# 13297                      0          0.0  17684
# 13298                      0          0.0  17684

# %% [markdown]
# We can see that there is a product id just forf orders (9999), that has cannot be specified as a unique product.
#
# On the other hand, we see that this product id has certain particularities: for instance, there are lots of orders with 0 units
# ordered, which seems extrange.

# %%
filter1=(totals_by_id_description['product_id']==9999) &  (totals_by_id_description['units_ordered_numeric']==0)
totals_by_id_description[filter1].head(10)
# Out:
#        product_id                                        description  section  \
# 19240      9999.0  Encargo CARTEL DE CHOCOLATE ´´ FELICIDADES MAMÁ´´        0
# 23171      9999.0                             EncargoROSCON 10R NATA        0
# 23172      9999.0                          EncargoROSCON 20 RACIONES        0
# 23243      9999.0                     EncargoSALSA DE MOSTAZA Y MIEL        0
# 19242      9999.0  Encargo CARTEL DE CHOCOLATE ´´ FELICIDADES MI ...        0
# 19241      9999.0  Encargo CARTEL DE CHOCOLATE ´´ FELICIDADES MAR...        0
# 23170      9999.0                                 EncargoROSCON 10R         0
# 23165      9999.0  EncargoROLLITOS DE LENGUADO CON LANGOSTINOS AL...        0
# 23164      9999.0  EncargoROLLITOS DE LENGUADO CON LANGOSTINOS 8 RAC        0
# 19243      9999.0  Encargo CARTEL DE CHOCOLATE ´´ FELICIDADES TRU...        0
#
#        units_ordered_numeric  sells_share
# 19240                      0          0.0
# 23171                      0          0.0
# 23172                      0          0.0
# 23243                      0          0.0
# 19242                      0          0.0
# 19241                      0          0.0
# 23170                      0          0.0
# 23165                      0          0.0
# 23164                      0          0.0
# 19243                      0          0.0

# %% [markdown]
# '
#
# So, lets take a look to the relationship between the id and its description:
#
#
# '

# %%
dif_id_description_matches=totals_by_id_description[['product_id','description']].sort_values('product_id', ascending=True)
dif_id_description_matches.head()
# Out:
#     product_id                                        description
# 0          1.0                    ARBOL DE NAVIDAD ROCA FILET PEQ
# 2          2.0  PASTA SABLE MANTEQUILLA BOLSA 150 GRS de san v...
# 1          2.0              PASTA SABLE MANTEQUILLA BOLSA 150 GRS
# 19        45.0                             POSTRE   SAN   HONORET
# 18        45.0                                    POSTRE   SACHER

# %%
prods_per_id=dif_id_description_matches.groupby('product_id', as_index=False).count().sort_values('description', ascending=False)

# %%
prods_per_id.head()
# Out:
#       product_id  description
# 1823      9999.0        17684
# 320        450.0         1152
# 287        414.0         1101
# 139        245.0          479
# 283        410.0          456

# %%
ppi50=prods_per_id[1:50]

names2=[str(x) for x in ppi50['product_id']]

plt.bar(names2, ppi50['description']);

# %%
#Keeping these lines just in case:

# searching_for_unique=totals_by_id_description[['product_id','description']]
# searching_for_unique['joined_cols']=searching_for_unique['product_id'].apply(str)+"/"+searching_for_unique['description']

# %% [markdown]
# '
#
#
# These results make us think again the groupby used.
#
# Is it, perhaps, more useful to group the products just by id?
#
#
#
# '

# %%
accesory_table2=df.groupby(['product_id'], as_index=False).first()[['product_id','description']]
df.head()
# Out:
#    product_id                description  order_date  section store  \
# 0       211.0        EMPANADILLAS SALMON  2009-06-12        0  BmUP
# 1      1231.0  MALLORCA CELOFAN VAINILLA  2009-06-13        0  BmUP
# 2      1233.0       ROCAS FILET VAINILLA  2009-06-13        0  BmUP
# 3      1234.0              LICOR GUINDAS  2009-06-13        0  BmUP
# 4      1235.0                 LICOR UVAS  2009-06-13        0  BmUP
#
#   units_ordered  units_ordered_numeric
# 0          0,00                      0
# 1          0,00                      0
# 2          1,00                      1
# 3          1,00                      1
# 4          1,00                      1

# %%
dict1={'units_ordered_numeric':'sum','description':'first','units_ordered':'count'}

totals_by_id=df.groupby(['product_id'], as_index=False).agg(dict1).sort_values('units_ordered_numeric', ascending=False)

list1=['product_id', 'total_orders', 'description', 'number_of_different_names']

totals_by_id.columns=list1

totals_by_id.head(20)
# Out:
#      product_id  total_orders              description  \
# 139       245.0         80052      Sandwiches Surtidos
# 56        150.0         62339         TORRIJAS GRANDES
# 154       271.0         59527       MINI QUICHES JAMON
# 155       272.0         54710      MINI QUICHES SALMON
# 20        112.0         35231                 TORTELES
# 99        203.0         31838         QUICHES DE QUESO
# 63        160.0         29137        TORRIJAS PEQUEÑAS
# 148       260.0         20792  QUICHES DE SALMON PÑOS.
# 48        140.0         20359                 PALMERAS
# 23        115.0         18450         BAGUETT MALLORCA
# 569       820.0         17414     SELVA NEGRA (POSTRE)
# 100       204.0         17396       QUICHES DE CEBOLLA
# 8         100.0         15693                CROISANTS
# 590       846.0         15249          POSTRE MILHOJAS
# 317       446.0         14942   POSTRE TARTALETA LIMON
# 568       816.0         14455   SAN MARQUITOS (POSTRE)
# 600       865.0         14071             POSTRE OPERA
# 47        139.0         13592      CHAPATITAS DE 40 GR
# 11        103.0         13296          CROISSANT PETIT
# 431       573.0         12413   CAJA ACETATO DE PASTAS
#
#      number_of_different_names
# 139                       2138
# 56                         692
# 154                       3385
# 155                       3234
# 20                        2805
# 99                        3846
# 63                         506
# 148                       2891
# 48                        3445
# 23                        2419
# 569                       3773
# 100                       3336
# 8                         2688
# 590                       3708
# 317                       3698
# 568                       3534
# 600                       3672
# 47                        2680
# 11                        3438
# 431                       1548

# %%
dict1={'units_ordered_numeric':'sum','description':'first','units_ordered':'count'}

totals_by_id_and_store=df.groupby(['product_id', 'store'], as_index=False).agg(dict1).sort_values(['store','units_ordered_numeric'], ascending=False)

list2=['product_id', 'store', 'total_orders', 'description', 'number_of_different_names']

totals_by_id_and_store.columns=list2

totals_by_id_and_store.head(20)
# Out:
#      product_id store  total_orders              description  \
# 139       245.0  BmUP         80052      Sandwiches Surtidos
# 56        150.0  BmUP         62339         TORRIJAS GRANDES
# 154       271.0  BmUP         59527       MINI QUICHES JAMON
# 155       272.0  BmUP         54710      MINI QUICHES SALMON
# 20        112.0  BmUP         35231                 TORTELES
# 99        203.0  BmUP         31838         QUICHES DE QUESO
# 63        160.0  BmUP         29137        TORRIJAS PEQUEÑAS
# 148       260.0  BmUP         20792  QUICHES DE SALMON PÑOS.
# 48        140.0  BmUP         20359                 PALMERAS
# 23        115.0  BmUP         18450         BAGUETT MALLORCA
# 569       820.0  BmUP         17414     SELVA NEGRA (POSTRE)
# 100       204.0  BmUP         17396       QUICHES DE CEBOLLA
# 8         100.0  BmUP         15693                CROISANTS
# 590       846.0  BmUP         15249          POSTRE MILHOJAS
# 317       446.0  BmUP         14942   POSTRE TARTALETA LIMON
# 568       816.0  BmUP         14455   SAN MARQUITOS (POSTRE)
# 600       865.0  BmUP         14071             POSTRE OPERA
# 47        139.0  BmUP         13592      CHAPATITAS DE 40 GR
# 11        103.0  BmUP         13296          CROISSANT PETIT
# 431       573.0  BmUP         12413   CAJA ACETATO DE PASTAS
#
#      number_of_different_names
# 139                       2138
# 56                         692
# 154                       3385
# 155                       3234
# 20                        2805
# 99                        3846
# 63                         506
# 148                       2891
# 48                        3445
# 23                        2419
# 569                       3773
# 100                       3336
# 8                         2688
# 590                       3708
# 317                       3698
# 568                       3534
# 600                       3672
# 47                        2680
# 11                        3438
# 431                       1548

# %% [markdown]
# # 4. ENDING<a id='a4'></a>

# %% [markdown]
# After all this process, we have learned a few things:
#
# -We have data related to orders of several products and stores. The products are marked by an id and a description.
#
# -Our data has null values, but very few, and we have then decided to discard them.
#
# -Our data has not a solid relationship between id and description of the products. In general, an id is assigned to many "similar" products. In a few cases, it has been noticed that an id is given to two disimilar products (we are assuming that this is due to human mistake).
#
# -Also, there is an id (9999) that, as it is used for direct orders from customers, is assigned to a lot of different products. We could try to reassign this products by its description to their other suitable id, or disregard the whole id. As we were asked not to take into account the direct online orders from customers, the solution should be to not use this id.
#
# -Appart from the stated, id seems a better indicator than description, for grouping the aforementioned products.
#
# -Some additional checks should be done to adress the suitability of the id as indicator of the product. Specifically, it would be interesting to check the behaviour of id against a manual filter based on some keywords.
#
# Taking into consideration that we have operated this script over one million lines, the results in terms of comparison of the sales of the different products should be relatively reliable.
